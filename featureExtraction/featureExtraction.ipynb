# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage.io import imread, imshow
# double dash to avoid syntax error
image = imread("C:\\Users\\Blobby\\Desktop\\trash\\trash1.jpg", as_gray=True)
imshow(image)

# %%
# checking image shape
image.shape, image
# Out:
# ((384, 512),
#  array([[0.85613608, 0.85613608, 0.85613608, ..., 0.81273098, 0.81273098,
#          0.81273098],
#         [0.85613608, 0.85613608, 0.85613608, ..., 0.81273098, 0.81273098,
#          0.81273098],
#         [0.85613608, 0.85613608, 0.85613608, ..., 0.81273098, 0.81273098,
#          0.81273098],
#         ...,
#         [0.86595137, 0.86595137, 0.86595137, ..., 0.30887333, 0.30495176,
#          0.30495176],
#         [0.86595137, 0.86595137, 0.86595137, ..., 0.30887333, 0.30887333,
#          0.30887333],
#         [0.86595137, 0.86595137, 0.86595137, ..., 0.3127949 , 0.30887333,
#          0.30887333]]))

# %%
# pixel features

features = image

features.shape, features
# Out:
# ((384, 512),
#  array([[0.85613608, 0.85613608, 0.85613608, ..., 0.81273098, 0.81273098,
#          0.81273098],
#         [0.85613608, 0.85613608, 0.85613608, ..., 0.81273098, 0.81273098,
#          0.81273098],
#         [0.85613608, 0.85613608, 0.85613608, ..., 0.81273098, 0.81273098,
#          0.81273098],
#         ...,
#         [0.86595137, 0.86595137, 0.86595137, ..., 0.30887333, 0.30495176,
#          0.30495176],
#         [0.86595137, 0.86595137, 0.86595137, ..., 0.30887333, 0.30887333,
#          0.30887333],
#         [0.86595137, 0.86595137, 0.86595137, ..., 0.3127949 , 0.30887333,
#          0.30887333]]))

# %%
image = imread("C:\\Users\\Blobby\\Desktop\\trash\\trash1.jpg")
image.shape
# Out:
# (384, 512, 3)

# %%
feature_matrix = np.zeros((384, 512))
feature_matrix.shape
# Out:
# (384, 512)

# %%
for i in range(0, image.shape[0]):
    for j in range(0, image.shape[1]):
        #print("int((image[i,j])):\n {}".format(int(image[i,j,0])))
        #print("j:\n {}".format(j))
        feature_matrix[i][j] = ((int(image[i,j,0]) + int(image[i,j,1]) + int(image[i,j,2]))/3)

# %%
features = np.reshape(feature_matrix, (384*512))
features.shape
# Out:
# (196608,)

# %%
# importing the required libraries
import numpy as np
from skimage.io import imread, imshow
from skimage.filters import prewitt_h,prewitt_v
import matplotlib.pyplot as plt
# %matplotlib inline

# reading the image
image = imread("C:\\Users\\Blobby\\Desktop\\glass\\glass23.jpg", as_gray=True)

# calculating horizontal edges using prewitt kernel
edges_prewitt_horizontal = prewitt_h(image)

#calculating vertical edges using prewitt kernel
edges_prewitt_vertical = prewitt_v(image)

imshow(edges_prewitt_vertical, cmap='gray')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage.io import imread, imshow
# double dash to avoid syntax error
image = imread("C:\\Users\\Blobby\\Desktop\\trash\\trash1.jpg")
imshow(image)

# %%
# checking image shape
image.shape, image
# Out:
# ((384, 512, 3),
#  array([[[233, 216, 198],
#          [233, 216, 198],
#          [233, 216, 198],
#          ...,
#          [221, 205, 189],
#          [221, 205, 189],
#          [221, 205, 189]],
#
#         [[233, 216, 198],
#          [233, 216, 198],
#          [233, 216, 198],
#          ...,
#          [221, 205, 189],
#          [221, 205, 189],
#          [221, 205, 189]],
#
#         [[233, 216, 198],
#          [233, 216, 198],
#          [233, 216, 198],
#          ...,
#          [221, 205, 189],
#          [221, 205, 189],
#          [221, 205, 189]],
#
#         ...,
#
#         [[234, 219, 200],
#          [234, 219, 200],
#          [234, 219, 200],
#          ...,
#          [ 86,  78,  65],
#          [ 85,  77,  64],
#          [ 85,  77,  64]],
#
#         [[234, 219, 200],
#          [234, 219, 200],
#          [234, 219, 200],
#          ...,
#          [ 86,  78,  65],
#          [ 86,  78,  65],
#          [ 86,  78,  65]],
#
#         [[234, 219, 200],
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
img_loc = []

from skimage.io import imread, imshow
# double dash to avoid syntax error
for index in range(5):
    img_loc.append("C:\\Users\\Blobby\\Desktop\\trash\\trash"+str(index+1)+".jpg")
#print(img_loc)
image1 = imread(img_loc[0], as_gray=True)
#print(image)    
imshow(image1)
#image2 = imread(img_loc[1], as_gray=True)
#print(image)    
#imshow(image2)
#image3 = imread(img_loc[2], as_gray=True)
#print(image)    
#imshow(image3)
#image4 = imread(img_loc[3], as_gray=True)
#print(image)    
#imshow(image4)
#image5 = imread(img_loc[4], as_gray=True)
#print(image)    
#imshow(image5)

# %%
import numpy as np
# read multiple images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def process(filename: str=None) -> None:
    """
    Veiw mutliple images stored in files, stacking vertically
    
    Arguments:
        filename: str - path to filename containing image
    """
    #original
    #image = mpimg.imread(filename)
    # grayscaled
    image = rgb2gray(mpimg.imread(filename))
    # <something gets done here>
    plt.figure()
    #color.rgb2gray(image)
    #plt.imshow(image)
    #show grayscaled image
    plt.imshow(image, cmap=plt.get_cmap('gray'))
    
    print(image.shape, image)

def rgb2gray(rgb):
    return np.dot(rgb[...,:3],[0.2989, 0.5870, 0.1140])

for i in range(10):
    file = "C:\\Users\\Blobby\\Desktop\\trash\\trash"+str(i+1)+".jpg"
    process(file)
# Out:
# (384, 512) [[219.0077 219.0077 219.0077 ... 207.9379 207.9379 207.9379]
#  [219.0077 219.0077 219.0077 ... 207.9379 207.9379 207.9379]
#  [219.0077 219.0077 219.0077 ... 207.9379 207.9379 207.9379]
#  ...
#  [221.2956 221.2956 221.2956 ...  78.9014  77.9015  77.9015]
#  [221.2956 221.2956 221.2956 ...  78.9014  78.9014  78.9014]
#  [221.2956 221.2956 221.2956 ...  79.9013  78.9014  78.9014]]
# (384, 512) [[226.6416 226.6416 226.6416 ... 188.0539 188.0539 188.0539]
#  [226.6416 226.6416 226.6416 ... 188.0539 188.0539 188.0539]
#  [226.6416 226.6416 226.6416 ... 188.0539 188.0539 188.0539]
#  ...
#  [201.812  201.812  201.812  ... 134.2073 134.2073 134.2073]
#  [201.812  201.812  201.812  ... 134.2073 134.2073 134.2073]
#  [201.812  201.812  201.812  ... 134.2073 134.2073 134.2073]]
# (384, 512) [[194.2983 194.2983 194.2983 ... 189.744  189.744  189.744 ]
#  [194.2983 194.2983 194.2983 ... 189.744  189.744  189.744 ]
#  [193.2984 193.2984 193.2984 ... 189.744  189.744  189.744 ]
# ...

# %%
# create csv file
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
header = ['filename', 'shape', 'array', 'indexes value']
data = []
image = ()
arr = []

def process(filename: str=None) -> None:
    """
    Veiw mutliple images stored in files, stacking vertically
    
    Arguments:
        filename: str - path to filename containing image
    """
    image = rgb2gray(mpimg.imread(filename))
    #plt.figure()
    #plt.imshow(image, cmap=plt.get_cmap('gray'))
    #print(len(image))
    #print(image.shape)
    """print(image.shape, image)
    print("hello\n")
    """
    """arr = [None]*len(image);"""
    print(type(image))
    #print(image.item(38))
    return [filename, image.shape, image];

def rgb2gray(rgb):
    return np.dot(rgb[...,:3],[0.2989, 0.5870, 0.1140])

for i in range(1):
    file = "C:\\Users\\Blobby\\Desktop\\trash\\trash"+str(i+1)+".jpg"
    data += [process(file)]
    print(len(image))
    print(image)
    for i in range(len(image)):
        arr += [image.item(i)];
    print("index", arr)
    with open('imageFeatures.csv', 'w', encoding='UTF8', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(header)
        # write multiple rows
        writer.writerows(data)
# Out:
# <class 'numpy.ndarray'>
# 0
# ()
# index []

# %%
# create csv file
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
header = ['filename', 'shape', 'array', 'indexes value']
data = []
arr = []

def rgb2gray(rgb):
    return np.dot(rgb[...,:3],[0.2989, 0.5870, 0.1140])

for i in range(1):
    file = "C:\\Users\\Blobby\\Desktop\\trash\\trash"+str(i+1)+".jpg"
    image = rgb2gray(mpimg.imread(file))

    for j in range(len(image)*512):
        arr += [image.item(j)];
    print("index\n{}".format(arr))
    
    data += [[file, image.shape, image, arr]]
    
    with open('imageFeatures.csv', 'w', encoding='UTF8', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(header)
        # write multiple rows
        writer.writerows(data)
# Out:
# index
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

trashnet = {}
data_category = []
data = []
file_dir = "C:\\Users\\Blobby\\Desktop\\"
categories = ["paper", "metal", "cardboard", "plastic","glass"]

def rgb2gray(rgb):
    return np.dot(rgb[...,:3],[0.2989, 0.5870, 0.1140])

for category in categories:
    for i in range(50):
        file = file_dir + category + "\\" + category + str(i+1) +".jpg"
        image = rgb2gray(mpimg.imread(file))
        data += [np.reshape(image, (384*512))]
        data_category += [categories.index(category)];
trashnet['data'] = np.array(data);       
trashnet['category'] = np.array(data_category)
print(trashnet['data'].shape)
# Out:
# (250, 196608)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

trashnet = {}
data_category = []
data = []
file_dir = "C:\\Users\\Blobby\\Desktop\\"
categories = ["paper", "metal", "cardboard", "plastic", "glass"]

def rgb2gray(rgb):
    return np.dot(rgb[...,:3],[0.2989, 0.5870, 0.1140])

for category in categories:
    for i in range(20):
        file = file_dir + category + "\\" + category + str(i+1) +".jpg"
        image = mpimg.imread(file)
        """data += [np.reshape(image, (384*512))]
        data_category += [categories.index(category)];
trashnet['data'] = np.array(data);       
trashnet['category'] = np.array(data_category)
#print(trashnet)"""

# %%
rgb_mean = np.zeros((384, 512))
rgb_mean.shape

for i in range(0, image.shape[0]):
    for j in range(0, image.shape[1]):
        rgb_mean[i][j] = ((int(image[i,j,0]) + int(image[i,j,1]) + int(image[i,j,2]))/3)
        
rgb_mean_1d = np.reshape(rgb_mean, (384*512))
rgb_mean_1d.shape
print(rgb_mean_1d)
# Out:
# [224.66666667 224.66666667 224.66666667 ... 144.33333333 144.33333333
#  144.33333333]

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(    
    trashnet['data'], trashnet['category'], test_size=0.2, random_state=0)

# %%
print(trashnet['data'].shape)
# Out:
# (250, 196608)

# %%
print(trashnet['category'].shape)
# Out:
# (250,)

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
data2 = []
image2 = rgb2gray(mpimg.imread("C:\\Users\\Blobby\\Desktop\\cardboard\\cardboard50.jpg"))
data2 = np.array([np.reshape(image, (384*512))])
print(data2.shape)
# Out:
# (1, 196608)

# %%
prediction = knn.predict(data2) 
print("Prediction: {}".format(prediction)) 
print("Predicted category: {}".format(       
    categories[prediction.item(0)]))
# Out:
# Prediction: [0]
# Predicted category: paper

# %%
y_pred = knn.predict(X_test) 
print("Test set predictions:\n {}".format(y_pred))
# Out:
# Test set predictions:
#  [4 2 2 3 3 3 3 4 3 3 1 0 4 2 4 4 4 2 3 3 3 3 4 2 3 4 2 3 0 0 4 4 4 0 3 4 4
#  3 2 2 4 3 0 3 3 3 3 0 3 3]

# %%
print("Test set score: {:.2f}".format(np.mean(y_pred == y_test)))
# Out:
# Test set score: 0.44

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy.stats import mode
import sys
np.set_printoptions(threshold=sys.maxsize)

trashnet = {}
data_category = []
data = []
file_dir = "C:\\Users\\Blobby\\Desktop\\"
categories = ["paper", "metal", "cardboard", "plastic", "glass"]

def rgb2gray(rgb):
    return np.dot(rgb[...,:3],[0.2989, 0.5870, 0.1140])

for category in categories:
    for i in range(20):
        file = file_dir + category + "\\" + category + str(i+1) +".jpg"
        image = rgb2gray(mpimg.imread(file))
        print(mode(image).count.shape)
        break
        data += ([np.reshape(image, (384*512))])
        data_category += [categories.index(category)];
    
    break
"""trashnet['data'] = np.array(data);       
trashnet['category'] = np.array(data_category)
print(trashnet['data'].shape)
print(mode(data))"""
# Out:
# (1, 512)
# "trashnet['data'] = np.array(data);       \ntrashnet['category'] = np.array(data_category)\nprint(trashnet['data'].shape)\nprint(mode(data))"
