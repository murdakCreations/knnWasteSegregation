# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage.io import imread, imshow
# double dash to avoid syntax error
image = imread("C:/Users/Blobby/Desktop/plastic/plastic100.jpg")
imshow(image)
print(image.shape)
# Out:
# (384, 512, 3)

# %%
import cv2
resizedImg = cv2.resize(image,(50,50))
plt.imshow(resizedImg, cmap = 'gray')
plt.show()

# %%
resizedImg
# Out:
# array([[[218, 220, 232],
#         [214, 216, 228],
#         [214, 216, 229],
#         ...,
#         [163, 164, 169],
#         [162, 163, 168],
#         [161, 162, 167]],
#
#        [[216, 218, 230],
#         [215, 217, 229],
#         [215, 217, 230],
#         ...,
#         [164, 165, 170],
#         [162, 163, 168],
#         [161, 163, 168]],
#
#        [[217, 216, 230],
#         [217, 216, 230],
#         [218, 218, 230],
#         ...,
#         [162, 165, 174],
#         [162, 162, 170],
#         [161, 162, 167]],
#
#        ...,
#
#        [[212, 214, 226],
#         [212, 214, 226],
#         [212, 214, 227],
#         ...,
#         [150, 150, 160],
#         [150, 150, 157],
#         [150, 150, 155]],
#
#        [[216, 215, 229],
#         [215, 214, 228],
#         [214, 213, 227],
#         ...,
#         [147, 148, 153],
#         [148, 147, 153],
#         [148, 147, 153]],
#
#        [[218, 217, 231],
#         [215, 214, 228],
#         [214, 213, 227],
#         ...,
#         [142, 143, 148],
#         [144, 143, 149],
#         [145, 144, 150]]], dtype=uint8)
