# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage.io import imread, imshow

image = imread("C:\\Users\\Blobby\\Desktop\\plastic\\plastic11.jpg")
imshow(image)

# %%
import csv
feature_matrix = np.zeros((image.shape[0], image.shape[1]))
header = []
for h in range(image.shape[0]):
    for i in range(image.shape[1]):
        feature_matrix[h][i] = ((int(image[0,i,0]) + int(image[0,i,1]) + int(image[0,i,2]))/3)

np.reshape(feature_matrix, (image.shape[0]*image.shape[1]))
mode(feature_matrix)
np.amin(feature_matrix)
np.amax(feature_matrix)
# Out:
# 199.0

# %%
from scipy.stats import mode

print(header)
#mode(header)
# Out:
# [[198219.33333333 197509.33333333 197312.33333333 196605.33333333
#   196409.33333333 195705.33333333 195510.33333333 194809.33333333
#   194615.33333333 194421.33333333 194227.33333333 194033.33333333
#   193839.33333333 193645.33333333 193451.33333333 193257.33333333
#   193560.33333333 193365.33333333 193170.33333333 192975.33333333
#   192780.33333333 192585.33333333 192390.33333333 192195.33333333
#   192489.33333333 192293.33333333 192097.33333333 191901.33333333
#   191705.33333333 191509.33333333 191313.33333333 191117.33333333
#   191402.33333333 191205.33333333 191008.33333333 190811.33333333
#   190614.33333333 190417.33333333 190220.33333333 190023.33333333
#   189826.33333333 189629.33333333 189432.33333333 189235.33333333
#   189038.33333333 188841.33333333 188644.33333333 188447.33333333
#   187785.33333333 187589.33333333 187393.33333333 187197.33333333
#   187001.33333333 186805.33333333 186609.33333333 186413.33333333
# ...
