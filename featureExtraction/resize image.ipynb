# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage.io import imread, imshow
# double dash to avoid syntax error
image = imread("C:/Users/Blobby/Desktop/plastic/plastic120.jpg", as_gray=True)
imshow(image)
print(image.shape)
# Out:
# (384, 512)

# %%
import cv2
resizedImg = cv2.resize(image,(30,30))
plt.imshow(resizedImg, cmap = 'gray')
plt.show()

# %%
print(resizedImg.shape)
# Out:
# (30, 30)

# %%
from scipy.stats import mode
print(mode(resizedImg))
# Out:
# ModeResult(mode=array([[0.82430235, 0.81814078, 0.84543477, 0.82430235, 0.86412118,
#         0.85627804, 0.48628749, 0.23819202, 0.88094627, 0.87702471,
#         0.87310314, 0.86861608, 0.53327804, 0.38752737, 0.35593216,
#         0.46492549, 0.46573608, 0.48818706, 0.48061176, 0.51198431,
#         0.43988505, 0.47776863, 0.35788431, 0.91285451, 0.90696078,
#         0.89911765, 0.65482667, 0.70151464, 0.73746235, 0.87920431]]), count=array([[5, 4, 2, 2, 2, 2, 1, 1, 2, 3, 2, 2, 1, 1, 1, 2, 2, 2, 2, 2, 1, 1,
#         1, 2, 2, 2, 2, 2, 2, 2]]))

# %%
print(np.sum(mode(resizedImg).count))
# Out:
# 58

# %%
print(np.max(resizedImg))
# Out:
# 0.9375231372549018

# %%
print(resizedImg[3][23])
# Out:
# 0.9128545098039216

# %%
print(np.min(resizedImg))
# Out:
# 0.23819201960784286

# %%
newImg = image.resize((100,100))
imshow(image)

# %%
print(image.shape)
# Out:
# (300, 450)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage.io import imread, imshow
# double dash to avoid syntax error
image2 = imread("C:/Users/Blobby/Desktop/enhanced/metal/metal6.jpg", as_gray=True)
imshow(image2)
print(image2.shape)
# Out:
# (68, 67)

# %%
newImg2 = image2.resize((68,67))
imshow(image2)

# %%
print(image2)
# Out:
# [[0.80770118 0.80770118 0.80770118 ... 0.76877529 0.77967686 0.77183373]
#  [0.77183373 0.7780102  0.77408863 ... 0.7536098  0.74968824 0.74576667]
#  [0.74576667 0.74968824 0.7536098  ... 0.80377961 0.80377961 0.80377961]
#  ...
#  [0.66538588 0.67715059 0.68891529 ... 0.80857216 0.80913765 0.80913765]
#  [0.81390039 0.8015702  0.79791647 ... 0.44317373 0.42944471 0.42160157]
#  [0.40367529 0.38406745 0.36474235 ... 0.7418451  0.7418451  0.74576667]]

# %%
import cv2
resizedImg = cv2.resize(image2,(50,50))
plt.imshow(resizedImg, cmap = 'gray')
plt.show()
